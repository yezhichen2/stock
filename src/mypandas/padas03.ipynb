# %%
import pandas as pd
import numpy as np

# %%
dates = pd.date_range('20130101', periods=20)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.arange(0, 20).reshape(20, 1), index=dates, columns=list('A'))

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2013-01-07</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2013-01-08</th>
#       <td>7</td>
#     </tr>
#     <tr>
# ...

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2013-01-07</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2013-01-08</th>
#       <td>7</td>
#     </tr>
#     <tr>
# ...

# %%
df.iloc[19]
# Out:
# A    19
# Name: 2013-01-20 00:00:00, dtype: int32

# %%
df.ix[19, 'A'] = 19.0

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-04</th>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-05</th>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-06</th>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-07</th>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>2013-01-08</th>
#       <td>7.0</td>
#     </tr>
#     <tr>
# ...
